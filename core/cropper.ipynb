# %%
import cv2
import sys
import os.path
import threading

def crop_portrait(filename, cascade_file = "./lbpcascade_animeface.xml"):
    cascade = cv2.CascadeClassifier(cascade_file)
    image = cv2.imread(filename, cv2.IMREAD_COLOR)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.equalizeHist(gray)
    
    faces = cascade.detectMultiScale(gray,
                                     # detector options
                                     scaleFactor = 1.1,
                                     minNeighbors = 1,
                                     minSize = (96, 96))
    out_name = '../datasets/danbooru-images/portrait/0{}-'.format(filename[45:-4])

    i = 1
    for (x, y, w, h) in faces:
        width = len(image[0])
        height = len(image)
        start_x = max(int(x - 0.15 * w), 0)
        start_y = max(int(y - 0.4 * h), 0)
        end_x = min(int(start_x + 1.3 * w), width)
        end_y = min(int(start_y + 1.3 * h), height)
        edge_len = min(end_x - start_x, end_y - start_y)
        end_x = start_x + edge_len
        end_y = start_y + edge_len
        #cv2.rectangle(image, (start_x, start_y), (end_x, end_y), (0, 0, 255), 2)
        cropped = image[start_y: end_y, start_x: end_x]
        cv2.imwrite(out_name + str(i) + ".jpg", cropped)
        i = i + 1

class Cropper(threading.Thread):
    def __init__(self, name, crop_list):
        threading.Thread.__init__(self)
        self.name = name
        self.crop_list = crop_list
        self.total = len(crop_list)
    
    def run(self):
        for i, image in enumerate(self.crop_list):
            crop_portrait(image)
            if i % 100 == 0:
                print("{}: croping............({}/{})".format(self.name, i, self.total))
                
def to_string(image):
    path = '../datasets/danbooru-images/danbooru-images/0{:03d}/{}'
    index = int(image[:-4]) % 1000
    return path.format(index, image)

# %%
import json

with open('crop_list.json', 'r') as f:
    clist = json.load(f)
clist = [to_string(img) for img in clist]
clist = clist[60000:]  # change

trisec = len(clist) // 3
threads = [
    Cropper("Cropper 1", clist[:trisec]),
    Cropper("Cropper 2", clist[trisec:2*trisec]),
    Cropper("Cropper 3", clist[2*trisec:])
]
for thread in threads:
    thread.start()
for thread in threads:
    thread.join()
# Out:
# Croper 2: croping............(0/42450)
# Croper 1: croping............(0/42450)
# Croper 3: croping............(0/42452)
# Croper 1: croping............(100/42450)
# Croper 2: croping............(100/42450)
# Croper 3: croping............(100/42452)
# Croper 3: croping............(200/42452)
# Croper 2: croping............(200/42450)
# Croper 1: croping............(200/42450)
# Croper 3: croping............(300/42452)
# Croper 2: croping............(300/42450)
# Croper 1: croping............(300/42450)
# Croper 3: croping............(400/42452)
# Croper 2: croping............(400/42450)
# Croper 1: croping............(400/42450)
# Croper 3: croping............(500/42452)
# Croper 2: croping............(500/42450)
# Croper 1: croping............(500/42450)
# Croper 3: croping............(600/42452)
# Croper 2: croping............(600/42450)
# Croper 1: croping............(600/42450)
# Croper 3: croping............(700/42452)
# Croper 2: croping............(700/42450)
# Croper 1: croping............(700/42450)
# Croper 3: croping............(800/42452)
# Croper 2: croping............(800/42450)
# Croper 1: croping............(800/42450)
# Croper 3: croping............(900/42452)
# Croper 2: croping............(900/42450)
# Croper 1: croping............(900/42450)
# Croper 3: croping............(1000/42452)
# Croper 2: croping............(1000/42450)
# Croper 1: croping............(1000/42450)
# Croper 3: croping............(1100/42452)
# Croper 2: croping............(1100/42450)
# Croper 1: croping............(1100/42450)
# Croper 3: croping............(1200/42452)
# Croper 2: croping............(1200/42450)
# Croper 1: croping............(1200/42450)
# Croper 3: croping............(1300/42452)
# Croper 2: croping............(1300/42450)
# Croper 1: croping............(1300/42450)
# Croper 3: croping............(1400/42452)
# Croper 2: croping............(1400/42450)
# Croper 1: croping............(1400/42450)
# Croper 3: croping............(1500/42452)
# Croper 2: croping............(1500/42450)
# Croper 1: croping............(1500/42450)
# Croper 3: croping............(1600/42452)
# Croper 2: croping............(1600/42450)
# Croper 1: croping............(1600/42450)
# Croper 3: croping............(1700/42452)
# Croper 2: croping............(1700/42450)
# Croper 1: croping............(1700/42450)
# Croper 3: croping............(1800/42452)
# Croper 2: croping............(1800/42450)
# Croper 1: croping............(1800/42450)
# Croper 3: croping............(1900/42452)
# Croper 2: croping............(1900/42450)
# Croper 1: croping............(1900/42450)
# Croper 3: croping............(2000/42452)
# Croper 2: croping............(2000/42450)
# Croper 1: croping............(2000/42450)
# Croper 3: croping............(2100/42452)
# Croper 2: croping............(2100/42450)
# Croper 1: croping............(2100/42450)
# Croper 3: croping............(2200/42452)
# Croper 2: croping............(2200/42450)
# Croper 1: croping............(2200/42450)
# Croper 3: croping............(2300/42452)
# Croper 2: croping............(2300/42450)
# Croper 1: croping............(2300/42450)
# Croper 3: croping............(2400/42452)
# Croper 2: croping............(2400/42450)
# Croper 1: croping............(2400/42450)
# Croper 3: croping............(2500/42452)
# Croper 2: croping............(2500/42450)
# Croper 1: croping............(2500/42450)
# Croper 3: croping............(2600/42452)
# Croper 2: croping............(2600/42450)
# Croper 1: croping............(2600/42450)
# Croper 3: croping............(2700/42452)
# Croper 2: croping............(2700/42450)
# Croper 1: croping............(2700/42450)
# Croper 3: croping............(2800/42452)
# Croper 2: croping............(2800/42450)
# Croper 1: croping............(2800/42450)
# Croper 3: croping............(2900/42452)
# Croper 2: croping............(2900/42450)
# Croper 1: croping............(2900/42450)
# Croper 3: croping............(3000/42452)
# Croper 2: croping............(3000/42450)
# Croper 1: croping............(3000/42450)
# Croper 3: croping............(3100/42452)
# Croper 2: croping............(3100/42450)
# Croper 1: croping............(3100/42450)
# Croper 3: croping............(3200/42452)
# Croper 2: croping............(3200/42450)
# Croper 1: croping............(3200/42450)
# Croper 3: croping............(3300/42452)
# Croper 2: croping............(3300/42450)
# Croper 1: croping............(3300/42450)
# Croper 3: croping............(3400/42452)
# Croper 2: croping............(3400/42450)
# Croper 1: croping............(3400/42450)
# Croper 3: croping............(3500/42452)
# Croper 2: croping............(3500/42450)
# Croper 1: croping............(3500/42450)
# Croper 3: croping............(3600/42452)
# Croper 2: croping............(3600/42450)
# Croper 1: croping............(3600/42450)
# Croper 3: croping............(3700/42452)
# Croper 2: croping............(3700/42450)
# Croper 1: croping............(3700/42450)
# Croper 3: croping............(3800/42452)
# Croper 2: croping............(3800/42450)
# Croper 1: croping............(3800/42450)
# Croper 3: croping............(3900/42452)
# Croper 2: croping............(3900/42450)
# Croper 1: croping............(3900/42450)
# Croper 3: croping............(4000/42452)
# Croper 2: croping............(4000/42450)
# Croper 1: croping............(4000/42450)
# Croper 3: croping............(4100/42452)
# Croper 2: croping............(4100/42450)
# Croper 3: croping............(4200/42452)
# Croper 1: croping............(4100/42450)
# Croper 2: croping............(4200/42450)
# Croper 1: croping............(4200/42450)
# Croper 3: croping............(4300/42452)
# Croper 2: croping............(4300/42450)
# Croper 3: croping............(4400/42452)
# Croper 1: croping............(4300/42450)
# Croper 2: croping............(4400/42450)
# Croper 3: croping............(4500/42452)
# Croper 1: croping............(4400/42450)
# Croper 2: croping............(4500/42450)
# Croper 3: croping............(4600/42452)
# Croper 1: croping............(4500/42450)
# Croper 2: croping............(4600/42450)
# Croper 3: croping............(4700/42452)
# Croper 1: croping............(4600/42450)
# Croper 2: croping............(4700/42450)
# Croper 3: croping............(4800/42452)
# Croper 1: croping............(4700/42450)
# Croper 2: croping............(4800/42450)
# Croper 3: croping............(4900/42452)
# Croper 1: croping............(4800/42450)
# Croper 2: croping............(4900/42450)
# Croper 3: croping............(5000/42452)
# Croper 1: croping............(4900/42450)
# Croper 2: croping............(5000/42450)
# Croper 3: croping............(5100/42452)
# Croper 1: croping............(5000/42450)
# Croper 2: croping............(5100/42450)
# Croper 3: croping............(5200/42452)
# Croper 1: croping............(5100/42450)
# Croper 2: croping............(5200/42450)
# Croper 3: croping............(5300/42452)
# Croper 1: croping............(5200/42450)
# Croper 2: croping............(5300/42450)
# Croper 3: croping............(5400/42452)
# Croper 1: croping............(5300/42450)
# Croper 2: croping............(5400/42450)
# Croper 3: croping............(5500/42452)
# Croper 1: croping............(5400/42450)
# Croper 2: croping............(5500/42450)
# Croper 3: croping............(5600/42452)
# Croper 1: croping............(5500/42450)
# Croper 2: croping............(5600/42450)
# Croper 3: croping............(5700/42452)
# Croper 1: croping............(5600/42450)
# Croper 2: croping............(5700/42450)
# Croper 3: croping............(5800/42452)
# Croper 1: croping............(5700/42450)
# Croper 2: croping............(5800/42450)
# Croper 3: croping............(5900/42452)
# Croper 2: croping............(5900/42450)
# Croper 1: croping............(5800/42450)
# Croper 3: croping............(6000/42452)
# Croper 2: croping............(6000/42450)
# Croper 1: croping............(5900/42450)
# Croper 3: croping............(6100/42452)
# Croper 2: croping............(6100/42450)
# Croper 1: croping............(6000/42450)
# Croper 3: croping............(6200/42452)
# Croper 2: croping............(6200/42450)
# Croper 1: croping............(6100/42450)
# Croper 3: croping............(6300/42452)
# Croper 2: croping............(6300/42450)
# Croper 1: croping............(6200/42450)
# Croper 3: croping............(6400/42452)
# Croper 2: croping............(6400/42450)
# Croper 1: croping............(6300/42450)
# Croper 3: croping............(6500/42452)
# Croper 2: croping............(6500/42450)
# Croper 1: croping............(6400/42450)
# Croper 3: croping............(6600/42452)
# Croper 2: croping............(6600/42450)
# Croper 1: croping............(6500/42450)
# Croper 3: croping............(6700/42452)
# Croper 2: croping............(6700/42450)
# Croper 1: croping............(6600/42450)
# Croper 3: croping............(6800/42452)
# Croper 2: croping............(6800/42450)
# Croper 1: croping............(6700/42450)
# Croper 3: croping............(6900/42452)
# Croper 2: croping............(6900/42450)
# Croper 1: croping............(6800/42450)
# Croper 3: croping............(7000/42452)
# Croper 2: croping............(7000/42450)
# Croper 1: croping............(6900/42450)
# Croper 3: croping............(7100/42452)
# Croper 2: croping............(7100/42450)
# Croper 1: croping............(7000/42450)
# Croper 3: croping............(7200/42452)
# Croper 2: croping............(7200/42450)
# Croper 1: croping............(7100/42450)
# Croper 3: croping............(7300/42452)
# Croper 2: croping............(7300/42450)
# Croper 1: croping............(7200/42450)
# Croper 3: croping............(7400/42452)
# Croper 2: croping............(7400/42450)
# Croper 1: croping............(7300/42450)
# Croper 3: croping............(7500/42452)
# Croper 2: croping............(7500/42450)
# Croper 1: croping............(7400/42450)
# Croper 3: croping............(7600/42452)
# Croper 2: croping............(7600/42450)
# Croper 1: croping............(7500/42450)
# Croper 3: croping............(7700/42452)
# Croper 2: croping............(7700/42450)
# Croper 1: croping............(7600/42450)
# Croper 3: croping............(7800/42452)
# Croper 2: croping............(7800/42450)
# Croper 1: croping............(7700/42450)
# Croper 3: croping............(7900/42452)
# Croper 2: croping............(7900/42450)
# Croper 1: croping............(7800/42450)
# Croper 3: croping............(8000/42452)
# Croper 2: croping............(8000/42450)
# Croper 1: croping............(7900/42450)
# Croper 3: croping............(8100/42452)
# Croper 2: croping............(8100/42450)
# Croper 1: croping............(8000/42450)
# Croper 3: croping............(8200/42452)
# Croper 2: croping............(8200/42450)
# Croper 1: croping............(8100/42450)
# Croper 3: croping............(8300/42452)
# Croper 2: croping............(8300/42450)
# Croper 1: croping............(8200/42450)
# Croper 3: croping............(8400/42452)
# Croper 2: croping............(8400/42450)
# Croper 1: croping............(8300/42450)
# Croper 3: croping............(8500/42452)
# Croper 2: croping............(8500/42450)
# Croper 1: croping............(8400/42450)
# Croper 3: croping............(8600/42452)
# Croper 2: croping............(8600/42450)
# Croper 1: croping............(8500/42450)
# Croper 3: croping............(8700/42452)
# Croper 2: croping............(8700/42450)
# Croper 1: croping............(8600/42450)
# Croper 3: croping............(8800/42452)
# Croper 2: croping............(8800/42450)
# Croper 1: croping............(8700/42450)
# Croper 3: croping............(8900/42452)
# Croper 2: croping............(8900/42450)
# Croper 1: croping............(8800/42450)
# Croper 3: croping............(9000/42452)
# Croper 2: croping............(9000/42450)
# Croper 3: croping............(9100/42452)
# Croper 1: croping............(8900/42450)
# Croper 2: croping............(9100/42450)
# Croper 3: croping............(9200/42452)
# Croper 1: croping............(9000/42450)
# Croper 2: croping............(9200/42450)
# Croper 3: croping............(9300/42452)
# Croper 1: croping............(9100/42450)
# Croper 2: croping............(9300/42450)
# Croper 3: croping............(9400/42452)
# Croper 1: croping............(9200/42450)
# Croper 2: croping............(9400/42450)
# Croper 3: croping............(9500/42452)
# Croper 1: croping............(9300/42450)
# Croper 2: croping............(9500/42450)
# Croper 3: croping............(9600/42452)
# Croper 1: croping............(9400/42450)
# Croper 2: croping............(9600/42450)
# Croper 3: croping............(9700/42452)
# Croper 1: croping............(9500/42450)
# Croper 2: croping............(9700/42450)
# Croper 3: croping............(9800/42452)
# Croper 1: croping............(9600/42450)
# Croper 2: croping............(9800/42450)
# Croper 3: croping............(9900/42452)
# Croper 1: croping............(9700/42450)
# Croper 2: croping............(9900/42450)
# Croper 3: croping............(10000/42452)
# Croper 1: croping............(9800/42450)
# Croper 2: croping............(10000/42450)
# Croper 3: croping............(10100/42452)
# Croper 1: croping............(9900/42450)
# Croper 2: croping............(10100/42450)
# Croper 3: croping............(10200/42452)
# Croper 1: croping............(10000/42450)
# Croper 2: croping............(10200/42450)
# Croper 3: croping............(10300/42452)
# Croper 1: croping............(10100/42450)
# Croper 2: croping............(10300/42450)
# Croper 3: croping............(10400/42452)
# Croper 1: croping............(10200/42450)
# Croper 2: croping............(10400/42450)
# Croper 3: croping............(10500/42452)
# Croper 1: croping............(10300/42450)
# Croper 2: croping............(10500/42450)
# Croper 3: croping............(10600/42452)
# Croper 1: croping............(10400/42450)
# Croper 2: croping............(10600/42450)
# Croper 3: croping............(10700/42452)
# Croper 1: croping............(10500/42450)
# Croper 2: croping............(10700/42450)
# Croper 3: croping............(10800/42452)
# Croper 1: croping............(10600/42450)
# Croper 2: croping............(10800/42450)
# Croper 3: croping............(10900/42452)
# Croper 1: croping............(10700/42450)
# Croper 2: croping............(10900/42450)
# Croper 3: croping............(11000/42452)
# Croper 1: croping............(10800/42450)
# Croper 3: croping............(11100/42452)
# Croper 2: croping............(11000/42450)
# Croper 1: croping............(10900/42450)
# Croper 2: croping............(11100/42450)
# Croper 3: croping............(11200/42452)
# Croper 1: croping............(11000/42450)
# Croper 3: croping............(11300/42452)
# Croper 2: croping............(11200/42450)
# Croper 1: croping............(11100/42450)
# Croper 3: croping............(11400/42452)
# Croper 2: croping............(11300/42450)
# Croper 1: croping............(11200/42450)
# Croper 3: croping............(11500/42452)
# Croper 2: croping............(11400/42450)
# Croper 1: croping............(11300/42450)
# Croper 3: croping............(11600/42452)
# Croper 2: croping............(11500/42450)
# Croper 1: croping............(11400/42450)
# Croper 3: croping............(11700/42452)
# Croper 2: croping............(11600/42450)
# Croper 1: croping............(11500/42450)
# Croper 3: croping............(11800/42452)
# Croper 2: croping............(11700/42450)
# Croper 1: croping............(11600/42450)
# Croper 3: croping............(11900/42452)
# Croper 2: croping............(11800/42450)
# Croper 1: croping............(11700/42450)
# Croper 3: croping............(12000/42452)
# Croper 2: croping............(11900/42450)
# Croper 1: croping............(11800/42450)
# Croper 3: croping............(12100/42452)
# Croper 2: croping............(12000/42450)
# Croper 1: croping............(11900/42450)
# Croper 3: croping............(12200/42452)
# Croper 1: croping............(12000/42450)
# Croper 2: croping............(12100/42450)
# Croper 3: croping............(12300/42452)
# Croper 1: croping............(12100/42450)
# Croper 2: croping............(12200/42450)
# Croper 3: croping............(12400/42452)
# Croper 1: croping............(12200/42450)
# Croper 2: croping............(12300/42450)
# Croper 3: croping............(12500/42452)
# Croper 1: croping............(12300/42450)
# Croper 2: croping............(12400/42450)
# Croper 3: croping............(12600/42452)
# Croper 1: croping............(12400/42450)
# Croper 2: croping............(12500/42450)
# Croper 3: croping............(12700/42452)
# Croper 1: croping............(12500/42450)
# Croper 2: croping............(12600/42450)
# Croper 3: croping............(12800/42452)
# Croper 1: croping............(12600/42450)
# Croper 2: croping............(12700/42450)
# Croper 3: croping............(12900/42452)
# Croper 1: croping............(12700/42450)
# Croper 2: croping............(12800/42450)
# Croper 3: croping............(13000/42452)
# Croper 1: croping............(12800/42450)
# Croper 2: croping............(12900/42450)
# Croper 3: croping............(13100/42452)
# Croper 1: croping............(12900/42450)
# Croper 2: croping............(13000/42450)
# Croper 3: croping............(13200/42452)
# Croper 1: croping............(13000/42450)
# Croper 2: croping............(13100/42450)
# Croper 3: croping............(13300/42452)
# Croper 1: croping............(13100/42450)
# Croper 2: croping............(13200/42450)
# Croper 3: croping............(13400/42452)
# Croper 1: croping............(13200/42450)
# Croper 2: croping............(13300/42450)
# Croper 3: croping............(13500/42452)
# Croper 1: croping............(13300/42450)
# Croper 2: croping............(13400/42450)
# Croper 3: croping............(13600/42452)
# Croper 1: croping............(13400/42450)
# Croper 2: croping............(13500/42450)
# Croper 3: croping............(13700/42452)
# Croper 1: croping............(13500/42450)
# Croper 2: croping............(13600/42450)
# Croper 3: croping............(13800/42452)
# Croper 1: croping............(13600/42450)
# Croper 2: croping............(13700/42450)
# Croper 3: croping............(13900/42452)
# Croper 1: croping............(13700/42450)
# Croper 2: croping............(13800/42450)
# Croper 3: croping............(14000/42452)
# Croper 1: croping............(13800/42450)
# Croper 2: croping............(13900/42450)
# Croper 3: croping............(14100/42452)
# Croper 1: croping............(13900/42450)
# Croper 2: croping............(14000/42450)
# Croper 3: croping............(14200/42452)
# Croper 1: croping............(14000/42450)
# Croper 2: croping............(14100/42450)
# Croper 3: croping............(14300/42452)
# Croper 1: croping............(14100/42450)
# Croper 2: croping............(14200/42450)
# Croper 3: croping............(14400/42452)
# Croper 1: croping............(14200/42450)
# Croper 2: croping............(14300/42450)
# Croper 3: croping............(14500/42452)
# Croper 1: croping............(14300/42450)
# Croper 2: croping............(14400/42450)
# Croper 3: croping............(14600/42452)
# Croper 1: croping............(14400/42450)
# Croper 2: croping............(14500/42450)
# Croper 3: croping............(14700/42452)
# Croper 1: croping............(14500/42450)
# Croper 2: croping............(14600/42450)
# Croper 3: croping............(14800/42452)
# Croper 1: croping............(14600/42450)
# Croper 2: croping............(14700/42450)
# Croper 3: croping............(14900/42452)
# Croper 1: croping............(14700/42450)
# Croper 2: croping............(14800/42450)
# Croper 3: croping............(15000/42452)
# Croper 1: croping............(14800/42450)
# Croper 2: croping............(14900/42450)
# Croper 3: croping............(15100/42452)
# Croper 1: croping............(14900/42450)
# Croper 2: croping............(15000/42450)
# Croper 3: croping............(15200/42452)
# Croper 1: croping............(15000/42450)
# Croper 2: croping............(15100/42450)
# Croper 1: croping............(15100/42450)
# Croper 3: croping............(15300/42452)
# Croper 2: croping............(15200/42450)
# Croper 1: croping............(15200/42450)
# Croper 3: croping............(15400/42452)
# Croper 2: croping............(15300/42450)
# Croper 1: croping............(15300/42450)
# Croper 3: croping............(15500/42452)
# Croper 2: croping............(15400/42450)
# Croper 3: croping............(15600/42452)
# Croper 1: croping............(15400/42450)
# Croper 2: croping............(15500/42450)
# Croper 3: croping............(15700/42452)
# Croper 1: croping............(15500/42450)
# Croper 2: croping............(15600/42450)
# Croper 3: croping............(15800/42452)
# Croper 1: croping............(15600/42450)
# Croper 2: croping............(15700/42450)
# Croper 3: croping............(15900/42452)
# Croper 1: croping............(15700/42450)
# Croper 2: croping............(15800/42450)
# Croper 3: croping............(16000/42452)
# Croper 1: croping............(15800/42450)
# Croper 2: croping............(15900/42450)
# Croper 3: croping............(16100/42452)
# Croper 1: croping............(15900/42450)
# Croper 2: croping............(16000/42450)
# Croper 3: croping............(16200/42452)
# Croper 1: croping............(16000/42450)
# Croper 2: croping............(16100/42450)
# Croper 3: croping............(16300/42452)
# Croper 1: croping............(16100/42450)
# Croper 2: croping............(16200/42450)
# Croper 3: croping............(16400/42452)
# Croper 1: croping............(16200/42450)
# Croper 2: croping............(16300/42450)
# Croper 3: croping............(16500/42452)
# Croper 1: croping............(16300/42450)
# Croper 2: croping............(16400/42450)
# Croper 3: croping............(16600/42452)
# Croper 1: croping............(16400/42450)
# Croper 2: croping............(16500/42450)
# Croper 3: croping............(16700/42452)
# Croper 1: croping............(16500/42450)
# Croper 2: croping............(16600/42450)
# Croper 3: croping............(16800/42452)
# Croper 1: croping............(16600/42450)
# Croper 2: croping............(16700/42450)
# Croper 3: croping............(16900/42452)
# Croper 1: croping............(16700/42450)
# Croper 2: croping............(16800/42450)
# Croper 3: croping............(17000/42452)
# Croper 1: croping............(16800/42450)
# Croper 2: croping............(16900/42450)
# Croper 3: croping............(17100/42452)
# Croper 1: croping............(16900/42450)
# Croper 2: croping............(17000/42450)
# Croper 3: croping............(17200/42452)
# Croper 1: croping............(17000/42450)
# Croper 2: croping............(17100/42450)
# Croper 3: croping............(17300/42452)
# Croper 1: croping............(17100/42450)
# Croper 2: croping............(17200/42450)
# Croper 3: croping............(17400/42452)
# Croper 1: croping............(17200/42450)
# Croper 2: croping............(17300/42450)
# Croper 3: croping............(17500/42452)
# Croper 1: croping............(17300/42450)
# Croper 2: croping............(17400/42450)
# Croper 3: croping............(17600/42452)
# Croper 1: croping............(17400/42450)
# Croper 2: croping............(17500/42450)
# Croper 3: croping............(17700/42452)
# Croper 1: croping............(17500/42450)
# Croper 2: croping............(17600/42450)
# Croper 3: croping............(17800/42452)
# Croper 1: croping............(17600/42450)
# Croper 2: croping............(17700/42450)
# Croper 3: croping............(17900/42452)
# Croper 1: croping............(17700/42450)
# Croper 2: croping............(17800/42450)
# Croper 3: croping............(18000/42452)
# Croper 1: croping............(17800/42450)
# Croper 2: croping............(17900/42450)
# Croper 3: croping............(18100/42452)
# Croper 1: croping............(17900/42450)
# Croper 2: croping............(18000/42450)
# Croper 3: croping............(18200/42452)
# Croper 1: croping............(18000/42450)
# Croper 2: croping............(18100/42450)
# Croper 3: croping............(18300/42452)
# Croper 1: croping............(18100/42450)
# Croper 2: croping............(18200/42450)
# Croper 3: croping............(18400/42452)
# Croper 1: croping............(18200/42450)
# Croper 2: croping............(18300/42450)
# Croper 3: croping............(18500/42452)
# Croper 1: croping............(18300/42450)
# Croper 2: croping............(18400/42450)
# Croper 3: croping............(18600/42452)
# Croper 1: croping............(18400/42450)
# Croper 2: croping............(18500/42450)
# Croper 3: croping............(18700/42452)
# Croper 1: croping............(18500/42450)
# Croper 2: croping............(18600/42450)
# Croper 3: croping............(18800/42452)
# Croper 1: croping............(18600/42450)
# Croper 2: croping............(18700/42450)
# Croper 3: croping............(18900/42452)
# Croper 1: croping............(18700/42450)
# Croper 2: croping............(18800/42450)
# Croper 3: croping............(19000/42452)
# Croper 1: croping............(18800/42450)
# Croper 2: croping............(18900/42450)
# Croper 1: croping............(18900/42450)
# Croper 3: croping............(19100/42452)
# Croper 2: croping............(19000/42450)
# Croper 3: croping............(19200/42452)
# Croper 1: croping............(19000/42450)
# Croper 2: croping............(19100/42450)
# Croper 3: croping............(19300/42452)
# Croper 1: croping............(19100/42450)
# Croper 2: croping............(19200/42450)
# Croper 3: croping............(19400/42452)
# Croper 1: croping............(19200/42450)
# Croper 2: croping............(19300/42450)
# Croper 1: croping............(19300/42450)
# Croper 3: croping............(19500/42452)
# Croper 2: croping............(19400/42450)
# Croper 1: croping............(19400/42450)
# Croper 3: croping............(19600/42452)
# Croper 2: croping............(19500/42450)
# Croper 1: croping............(19500/42450)
# Croper 3: croping............(19700/42452)
# Croper 2: croping............(19600/42450)
# Croper 1: croping............(19600/42450)
# Croper 3: croping............(19800/42452)
# Croper 2: croping............(19700/42450)
# Croper 1: croping............(19700/42450)
# Croper 3: croping............(19900/42452)
# Croper 2: croping............(19800/42450)
# Croper 1: croping............(19800/42450)
# Croper 3: croping............(20000/42452)
# Croper 2: croping............(19900/42450)
# Croper 1: croping............(19900/42450)
# Croper 3: croping............(20100/42452)
# Croper 2: croping............(20000/42450)
# Croper 1: croping............(20000/42450)
# Croper 3: croping............(20200/42452)
# Croper 2: croping............(20100/42450)
# Croper 1: croping............(20100/42450)
# Croper 3: croping............(20300/42452)
# Croper 2: croping............(20200/42450)
# Croper 1: croping............(20200/42450)
# Croper 3: croping............(20400/42452)
# Croper 2: croping............(20300/42450)
# Croper 1: croping............(20300/42450)
# Croper 3: croping............(20500/42452)
# Croper 2: croping............(20400/42450)
# Croper 1: croping............(20400/42450)
# Croper 3: croping............(20600/42452)
# Croper 2: croping............(20500/42450)
# Croper 1: croping............(20500/42450)
# Croper 3: croping............(20700/42452)
# Croper 2: croping............(20600/42450)
# Croper 1: croping............(20600/42450)
# Croper 3: croping............(20800/42452)
# Croper 2: croping............(20700/42450)
# Croper 1: croping............(20700/42450)
# Croper 3: croping............(20900/42452)
# Croper 2: croping............(20800/42450)
# Croper 1: croping............(20800/42450)
# Croper 3: croping............(21000/42452)
# Croper 2: croping............(20900/42450)
# Croper 1: croping............(20900/42450)
# Croper 3: croping............(21100/42452)
# Croper 2: croping............(21000/42450)
# Croper 1: croping............(21000/42450)
# Croper 3: croping............(21200/42452)
# Croper 2: croping............(21100/42450)
# Croper 1: croping............(21100/42450)
# Croper 2: croping............(21200/42450)
# Croper 3: croping............(21300/42452)
# Croper 1: croping............(21200/42450)
# Croper 2: croping............(21300/42450)
# Croper 3: croping............(21400/42452)
# Croper 1: croping............(21300/42450)
# Croper 2: croping............(21400/42450)
# Croper 3: croping............(21500/42452)
# Croper 1: croping............(21400/42450)
# Croper 2: croping............(21500/42450)
# Croper 3: croping............(21600/42452)
# Croper 1: croping............(21500/42450)
# Croper 2: croping............(21600/42450)
# Croper 3: croping............(21700/42452)
# Croper 1: croping............(21600/42450)
# Croper 2: croping............(21700/42450)
# Croper 3: croping............(21800/42452)
# Croper 1: croping............(21700/42450)
# Croper 2: croping............(21800/42450)
# Croper 3: croping............(21900/42452)
# Croper 1: croping............(21800/42450)
# Croper 3: croping............(22000/42452)
# Croper 2: croping............(21900/42450)
# Croper 1: croping............(21900/42450)
# Croper 3: croping............(22100/42452)
# Croper 2: croping............(22000/42450)
# Croper 1: croping............(22000/42450)
# Croper 3: croping............(22200/42452)
# Croper 2: croping............(22100/42450)
# Croper 1: croping............(22100/42450)
# Croper 3: croping............(22300/42452)
# Croper 2: croping............(22200/42450)
# Croper 1: croping............(22200/42450)
# Croper 3: croping............(22400/42452)
# Croper 2: croping............(22300/42450)
# Croper 1: croping............(22300/42450)
# Croper 3: croping............(22500/42452)
# Croper 2: croping............(22400/42450)
# Croper 1: croping............(22400/42450)
# Croper 2: croping............(22500/42450)
# Croper 3: croping............(22600/42452)
# Croper 1: croping............(22500/42450)
# Croper 2: croping............(22600/42450)
# Croper 3: croping............(22700/42452)
# Croper 1: croping............(22600/42450)
# Croper 2: croping............(22700/42450)
# Croper 3: croping............(22800/42452)
# Croper 1: croping............(22700/42450)
# Croper 2: croping............(22800/42450)
# Croper 3: croping............(22900/42452)
# Croper 1: croping............(22800/42450)
# Croper 2: croping............(22900/42450)
# Croper 3: croping............(23000/42452)
# Croper 1: croping............(22900/42450)
# Croper 2: croping............(23000/42450)
# Croper 3: croping............(23100/42452)
# Croper 1: croping............(23000/42450)
# Croper 2: croping............(23100/42450)
# Croper 3: croping............(23200/42452)
# Croper 1: croping............(23100/42450)
# Croper 2: croping............(23200/42450)
# Croper 3: croping............(23300/42452)
# Croper 1: croping............(23200/42450)
# Croper 2: croping............(23300/42450)
# Croper 3: croping............(23400/42452)
# Croper 1: croping............(23300/42450)
# Croper 2: croping............(23400/42450)
# Croper 3: croping............(23500/42452)
# Croper 1: croping............(23400/42450)
# Croper 2: croping............(23500/42450)
# Croper 3: croping............(23600/42452)
# Croper 1: croping............(23500/42450)
# Croper 2: croping............(23600/42450)
# Croper 3: croping............(23700/42452)
# Croper 1: croping............(23600/42450)
# Croper 2: croping............(23700/42450)
# Croper 3: croping............(23800/42452)
# Croper 1: croping............(23700/42450)
# Croper 2: croping............(23800/42450)
# Croper 3: croping............(23900/42452)
# Croper 1: croping............(23800/42450)
# Croper 2: croping............(23900/42450)
# Croper 3: croping............(24000/42452)
# Croper 1: croping............(23900/42450)
# Croper 2: croping............(24000/42450)
# Croper 3: croping............(24100/42452)
# Croper 1: croping............(24000/42450)
# Croper 2: croping............(24100/42450)
# Croper 3: croping............(24200/42452)
# Croper 1: croping............(24100/42450)
# Croper 2: croping............(24200/42450)
# Croper 3: croping............(24300/42452)
# Croper 1: croping............(24200/42450)
# Croper 3: croping............(24400/42452)
# Croper 2: croping............(24300/42450)
# Croper 1: croping............(24300/42450)
# Croper 2: croping............(24400/42450)
# Croper 3: croping............(24500/42452)
# Croper 1: croping............(24400/42450)
# Croper 2: croping............(24500/42450)
# Croper 3: croping............(24600/42452)
# Croper 1: croping............(24500/42450)
# Croper 2: croping............(24600/42450)
# Croper 3: croping............(24700/42452)
# Croper 1: croping............(24600/42450)
# Croper 2: croping............(24700/42450)
# Croper 3: croping............(24800/42452)
# Croper 1: croping............(24700/42450)
# Croper 2: croping............(24800/42450)
# Croper 3: croping............(24900/42452)
# Croper 1: croping............(24800/42450)
# Croper 2: croping............(24900/42450)
# Croper 3: croping............(25000/42452)
# Croper 1: croping............(24900/42450)
# Croper 2: croping............(25000/42450)
# Croper 3: croping............(25100/42452)
# Croper 1: croping............(25000/42450)
# Croper 2: croping............(25100/42450)
# Croper 3: croping............(25200/42452)
# Croper 1: croping............(25100/42450)
# Croper 2: croping............(25200/42450)
# Croper 3: croping............(25300/42452)
# Croper 1: croping............(25200/42450)
# Croper 2: croping............(25300/42450)
# Croper 3: croping............(25400/42452)
# Croper 1: croping............(25300/42450)
# Croper 2: croping............(25400/42450)
# Croper 3: croping............(25500/42452)
# Croper 1: croping............(25400/42450)
# Croper 2: croping............(25500/42450)
# Croper 3: croping............(25600/42452)
# Croper 1: croping............(25500/42450)
# Croper 2: croping............(25600/42450)
# Croper 3: croping............(25700/42452)
# Croper 1: croping............(25600/42450)
# Croper 2: croping............(25700/42450)
# Croper 3: croping............(25800/42452)
# Croper 1: croping............(25700/42450)
# Croper 2: croping............(25800/42450)
# Croper 3: croping............(25900/42452)
# Croper 1: croping............(25800/42450)
# Croper 2: croping............(25900/42450)
# Croper 3: croping............(26000/42452)
# Croper 1: croping............(25900/42450)
# Croper 2: croping............(26000/42450)
# Croper 3: croping............(26100/42452)
# Croper 1: croping............(26000/42450)
# Croper 2: croping............(26100/42450)
# Croper 3: croping............(26200/42452)
# Croper 1: croping............(26100/42450)
# Croper 2: croping............(26200/42450)
# Croper 3: croping............(26300/42452)
# Croper 1: croping............(26200/42450)
# Croper 2: croping............(26300/42450)
# Croper 3: croping............(26400/42452)
# Croper 1: croping............(26300/42450)
# Croper 2: croping............(26400/42450)
# Croper 3: croping............(26500/42452)
# Croper 1: croping............(26400/42450)
# Croper 2: croping............(26500/42450)
# Croper 3: croping............(26600/42452)
# Croper 1: croping............(26500/42450)
# Croper 2: croping............(26600/42450)
# Croper 3: croping............(26700/42452)
# Croper 1: croping............(26600/42450)
# Croper 2: croping............(26700/42450)
# Croper 3: croping............(26800/42452)
# Croper 1: croping............(26700/42450)
# Croper 2: croping............(26800/42450)
# Croper 3: croping............(26900/42452)
# Croper 1: croping............(26800/42450)
# Croper 2: croping............(26900/42450)
# Croper 3: croping............(27000/42452)
# Croper 1: croping............(26900/42450)
# Croper 2: croping............(27000/42450)
# Croper 1: croping............(27000/42450)
# Croper 3: croping............(27100/42452)
# Croper 2: croping............(27100/42450)
# Croper 3: croping............(27200/42452)
# Croper 1: croping............(27100/42450)
# Croper 2: croping............(27200/42450)
# Croper 1: croping............(27200/42450)
# Croper 3: croping............(27300/42452)
# Croper 2: croping............(27300/42450)
# Croper 1: croping............(27300/42450)
# Croper 3: croping............(27400/42452)
# Croper 2: croping............(27400/42450)
# Croper 1: croping............(27400/42450)
# Croper 3: croping............(27500/42452)
# Croper 2: croping............(27500/42450)
# Croper 1: croping............(27500/42450)
# Croper 3: croping............(27600/42452)
# Croper 2: croping............(27600/42450)
# Croper 1: croping............(27600/42450)
# Croper 3: croping............(27700/42452)
# Croper 2: croping............(27700/42450)
# Croper 1: croping............(27700/42450)
# Croper 3: croping............(27800/42452)
# Croper 2: croping............(27800/42450)
# Croper 1: croping............(27800/42450)
# Croper 3: croping............(27900/42452)
# Croper 2: croping............(27900/42450)
# Croper 1: croping............(27900/42450)
# Croper 3: croping............(28000/42452)
# Croper 2: croping............(28000/42450)
# Croper 1: croping............(28000/42450)
# Croper 3: croping............(28100/42452)
# Croper 2: croping............(28100/42450)
# Croper 1: croping............(28100/42450)
# Croper 3: croping............(28200/42452)
# Croper 2: croping............(28200/42450)
# Croper 1: croping............(28200/42450)
# Croper 3: croping............(28300/42452)
# Croper 2: croping............(28300/42450)
# Croper 1: croping............(28300/42450)
# Croper 3: croping............(28400/42452)
# Croper 2: croping............(28400/42450)
# Croper 1: croping............(28400/42450)
# Croper 3: croping............(28500/42452)
# Croper 2: croping............(28500/42450)
# Croper 1: croping............(28500/42450)
# Croper 3: croping............(28600/42452)
# Croper 2: croping............(28600/42450)
# Croper 1: croping............(28600/42450)
# Croper 3: croping............(28700/42452)
# Croper 2: croping............(28700/42450)
# Croper 1: croping............(28700/42450)
# Croper 3: croping............(28800/42452)
# Croper 2: croping............(28800/42450)
# Croper 1: croping............(28800/42450)
# Croper 3: croping............(28900/42452)
# Croper 2: croping............(28900/42450)
# Croper 1: croping............(28900/42450)
# Croper 3: croping............(29000/42452)
# Croper 2: croping............(29000/42450)
# Croper 1: croping............(29000/42450)
# Croper 3: croping............(29100/42452)
# Croper 2: croping............(29100/42450)
# Croper 1: croping............(29100/42450)
# Croper 3: croping............(29200/42452)
# Croper 2: croping............(29200/42450)
# Croper 1: croping............(29200/42450)
# Croper 3: croping............(29300/42452)
# Croper 2: croping............(29300/42450)
# Croper 1: croping............(29300/42450)
# Croper 3: croping............(29400/42452)
# Croper 2: croping............(29400/42450)
# Croper 1: croping............(29400/42450)
# Croper 3: croping............(29500/42452)
# Croper 2: croping............(29500/42450)
# Croper 1: croping............(29500/42450)
# Croper 3: croping............(29600/42452)
# Croper 2: croping............(29600/42450)
# Croper 1: croping............(29600/42450)
# Croper 3: croping............(29700/42452)
# Croper 2: croping............(29700/42450)
# Croper 1: croping............(29700/42450)
# Croper 3: croping............(29800/42452)
# Croper 2: croping............(29800/42450)
# Croper 1: croping............(29800/42450)
# Croper 3: croping............(29900/42452)
# Croper 2: croping............(29900/42450)
# Croper 1: croping............(29900/42450)
# Croper 3: croping............(30000/42452)
# Croper 2: croping............(30000/42450)
# Croper 1: croping............(30000/42450)
# Croper 3: croping............(30100/42452)
# Croper 2: croping............(30100/42450)
# Croper 1: croping............(30100/42450)
# Croper 3: croping............(30200/42452)
# Croper 2: croping............(30200/42450)
# Croper 1: croping............(30200/42450)
# Croper 3: croping............(30300/42452)
# Croper 2: croping............(30300/42450)
# Croper 1: croping............(30300/42450)
# Croper 3: croping............(30400/42452)
# Croper 2: croping............(30400/42450)
# Croper 1: croping............(30400/42450)
# Croper 3: croping............(30500/42452)
# Croper 2: croping............(30500/42450)
# Croper 1: croping............(30500/42450)
# Croper 3: croping............(30600/42452)
# Croper 2: croping............(30600/42450)
# Croper 1: croping............(30600/42450)
# Croper 3: croping............(30700/42452)
# Croper 2: croping............(30700/42450)
# Croper 1: croping............(30700/42450)
# Croper 3: croping............(30800/42452)
# Croper 2: croping............(30800/42450)
# Croper 1: croping............(30800/42450)
# Croper 3: croping............(30900/42452)
# Croper 2: croping............(30900/42450)
# Croper 1: croping............(30900/42450)
# Croper 3: croping............(31000/42452)
# Croper 2: croping............(31000/42450)
# Croper 1: croping............(31000/42450)
# Croper 3: croping............(31100/42452)
# Croper 2: croping............(31100/42450)
# Croper 1: croping............(31100/42450)
# Croper 3: croping............(31200/42452)
# Croper 2: croping............(31200/42450)
# Croper 1: croping............(31200/42450)
# Croper 3: croping............(31300/42452)
# Croper 2: croping............(31300/42450)
# Croper 1: croping............(31300/42450)
# Croper 3: croping............(31400/42452)
# Croper 2: croping............(31400/42450)
# Croper 1: croping............(31400/42450)
# Croper 3: croping............(31500/42452)
# Croper 2: croping............(31500/42450)
# Croper 1: croping............(31500/42450)
# Croper 3: croping............(31600/42452)
# Croper 2: croping............(31600/42450)
# Croper 3: croping............(31700/42452)
# Croper 1: croping............(31600/42450)
# Croper 2: croping............(31700/42450)
# Croper 3: croping............(31800/42452)
# Croper 1: croping............(31700/42450)
# Croper 2: croping............(31800/42450)
# Croper 3: croping............(31900/42452)
# Croper 1: croping............(31800/42450)
# Croper 2: croping............(31900/42450)
# Croper 3: croping............(32000/42452)
# Croper 1: croping............(31900/42450)
# Croper 2: croping............(32000/42450)
# Croper 3: croping............(32100/42452)
# Croper 1: croping............(32000/42450)
# Croper 2: croping............(32100/42450)
# Croper 3: croping............(32200/42452)
# Croper 1: croping............(32100/42450)
# Croper 2: croping............(32200/42450)
# Croper 3: croping............(32300/42452)
# Croper 1: croping............(32200/42450)
# Croper 2: croping............(32300/42450)
# Croper 3: croping............(32400/42452)
# Croper 1: croping............(32300/42450)
# Croper 2: croping............(32400/42450)
# Croper 3: croping............(32500/42452)
# Croper 1: croping............(32400/42450)
# Croper 2: croping............(32500/42450)
# Croper 3: croping............(32600/42452)
# Croper 1: croping............(32500/42450)
# Croper 2: croping............(32600/42450)
# Croper 1: croping............(32600/42450)
# Croper 3: croping............(32700/42452)
# Croper 2: croping............(32700/42450)
# Croper 1: croping............(32700/42450)
# Croper 3: croping............(32800/42452)
# Croper 2: croping............(32800/42450)
# Croper 1: croping............(32800/42450)
# Croper 3: croping............(32900/42452)
# Croper 2: croping............(32900/42450)
# Croper 1: croping............(32900/42450)
# Croper 3: croping............(33000/42452)
# Croper 2: croping............(33000/42450)
# Croper 1: croping............(33000/42450)
# Croper 3: croping............(33100/42452)
# Croper 2: croping............(33100/42450)
# Croper 1: croping............(33100/42450)
# Croper 3: croping............(33200/42452)
# Croper 2: croping............(33200/42450)
# Croper 1: croping............(33200/42450)
# Croper 3: croping............(33300/42452)
# Croper 2: croping............(33300/42450)
# Croper 1: croping............(33300/42450)
# Croper 3: croping............(33400/42452)
# Croper 2: croping............(33400/42450)
# Croper 1: croping............(33400/42450)
# Croper 3: croping............(33500/42452)
# Croper 2: croping............(33500/42450)
# Croper 1: croping............(33500/42450)
# Croper 3: croping............(33600/42452)
# Croper 2: croping............(33600/42450)
# Croper 1: croping............(33600/42450)
# Croper 2: croping............(33700/42450)
# Croper 3: croping............(33700/42452)
# Croper 1: croping............(33700/42450)
# Croper 2: croping............(33800/42450)
# Croper 3: croping............(33800/42452)
# Croper 1: croping............(33800/42450)
# Croper 2: croping............(33900/42450)
# Croper 3: croping............(33900/42452)
# Croper 1: croping............(33900/42450)
# Croper 2: croping............(34000/42450)
# Croper 3: croping............(34000/42452)
# Croper 1: croping............(34000/42450)
# Croper 2: croping............(34100/42450)
# Croper 3: croping............(34100/42452)
# Croper 1: croping............(34100/42450)
# Croper 2: croping............(34200/42450)
# Croper 3: croping............(34200/42452)
# Croper 1: croping............(34200/42450)
# Croper 2: croping............(34300/42450)
# Croper 3: croping............(34300/42452)
# Croper 1: croping............(34300/42450)
# Croper 2: croping............(34400/42450)
# Croper 3: croping............(34400/42452)
# Croper 1: croping............(34400/42450)
# Croper 2: croping............(34500/42450)
# Croper 3: croping............(34500/42452)
# Croper 1: croping............(34500/42450)
# Croper 2: croping............(34600/42450)
# Croper 3: croping............(34600/42452)
# Croper 2: croping............(34700/42450)
# Croper 1: croping............(34600/42450)
# Croper 3: croping............(34700/42452)
# Croper 1: croping............(34700/42450)
# Croper 2: croping............(34800/42450)
# Croper 3: croping............(34800/42452)
# Croper 1: croping............(34800/42450)
# Croper 2: croping............(34900/42450)
# Croper 3: croping............(34900/42452)
# Croper 1: croping............(34900/42450)
# Croper 2: croping............(35000/42450)
# Croper 3: croping............(35000/42452)
# Croper 1: croping............(35000/42450)
# Croper 2: croping............(35100/42450)
# Croper 3: croping............(35100/42452)
# Croper 1: croping............(35100/42450)
# Croper 2: croping............(35200/42450)
# Croper 3: croping............(35200/42452)
# Croper 1: croping............(35200/42450)
# Croper 2: croping............(35300/42450)
# Croper 3: croping............(35300/42452)
# Croper 1: croping............(35300/42450)
# Croper 2: croping............(35400/42450)
# Croper 3: croping............(35400/42452)
# Croper 1: croping............(35400/42450)
# Croper 2: croping............(35500/42450)
# Croper 3: croping............(35500/42452)
# Croper 1: croping............(35500/42450)
# Croper 2: croping............(35600/42450)
# Croper 3: croping............(35600/42452)
# Croper 1: croping............(35600/42450)
# Croper 2: croping............(35700/42450)
# Croper 3: croping............(35700/42452)
# Croper 1: croping............(35700/42450)
# Croper 2: croping............(35800/42450)
# Croper 3: croping............(35800/42452)
# Croper 1: croping............(35800/42450)
# Croper 2: croping............(35900/42450)
# Croper 3: croping............(35900/42452)
# Croper 1: croping............(35900/42450)
# Croper 2: croping............(36000/42450)
# Croper 3: croping............(36000/42452)
# Croper 1: croping............(36000/42450)
# Croper 2: croping............(36100/42450)
# Croper 3: croping............(36100/42452)
# Croper 1: croping............(36100/42450)
# Croper 2: croping............(36200/42450)
# Croper 3: croping............(36200/42452)
# Croper 1: croping............(36200/42450)
# Croper 2: croping............(36300/42450)
# Croper 3: croping............(36300/42452)
# Croper 1: croping............(36300/42450)
# Croper 2: croping............(36400/42450)
# Croper 3: croping............(36400/42452)
# Croper 2: croping............(36500/42450)
# Croper 1: croping............(36400/42450)
# Croper 3: croping............(36500/42452)
# Croper 2: croping............(36600/42450)
# Croper 1: croping............(36500/42450)
# Croper 3: croping............(36600/42452)
# Croper 2: croping............(36700/42450)
# Croper 1: croping............(36600/42450)
# Croper 3: croping............(36700/42452)
# Croper 2: croping............(36800/42450)
# Croper 1: croping............(36700/42450)
# Croper 3: croping............(36800/42452)
# Croper 2: croping............(36900/42450)
# Croper 1: croping............(36800/42450)
# Croper 3: croping............(36900/42452)
# Croper 2: croping............(37000/42450)
# Croper 3: croping............(37000/42452)
# Croper 1: croping............(36900/42450)
# Croper 2: croping............(37100/42450)
# Croper 3: croping............(37100/42452)
# Croper 1: croping............(37000/42450)
# Croper 2: croping............(37200/42450)
# Croper 3: croping............(37200/42452)
# Croper 1: croping............(37100/42450)
# Croper 2: croping............(37300/42450)
# Croper 3: croping............(37300/42452)
# Croper 1: croping............(37200/42450)
# Croper 2: croping............(37400/42450)
# Croper 3: croping............(37400/42452)
# Croper 1: croping............(37300/42450)
# Croper 2: croping............(37500/42450)
# Croper 3: croping............(37500/42452)
# Croper 1: croping............(37400/42450)
# Croper 2: croping............(37600/42450)
# Croper 3: croping............(37600/42452)
# Croper 1: croping............(37500/42450)
# Croper 2: croping............(37700/42450)
# Croper 3: croping............(37700/42452)
# Croper 1: croping............(37600/42450)
# Croper 2: croping............(37800/42450)
# Croper 3: croping............(37800/42452)
# Croper 1: croping............(37700/42450)
# Croper 2: croping............(37900/42450)
# Croper 3: croping............(37900/42452)
# Croper 1: croping............(37800/42450)
# Croper 2: croping............(38000/42450)
# Croper 3: croping............(38000/42452)
# Croper 1: croping............(37900/42450)
# Croper 2: croping............(38100/42450)
# Croper 3: croping............(38100/42452)
# Croper 1: croping............(38000/42450)
# Croper 2: croping............(38200/42450)
# Croper 3: croping............(38200/42452)
# Croper 1: croping............(38100/42450)
# Croper 2: croping............(38300/42450)
# Croper 1: croping............(38200/42450)
# Croper 3: croping............(38300/42452)
# Croper 2: croping............(38400/42450)
# Croper 1: croping............(38300/42450)
# Croper 3: croping............(38400/42452)
# Croper 2: croping............(38500/42450)
# Croper 1: croping............(38400/42450)
# Croper 3: croping............(38500/42452)
# Croper 2: croping............(38600/42450)
# Croper 1: croping............(38500/42450)
# Croper 3: croping............(38600/42452)
# Croper 2: croping............(38700/42450)
# Croper 1: croping............(38600/42450)
# Croper 3: croping............(38700/42452)
# Croper 2: croping............(38800/42450)
# Croper 1: croping............(38700/42450)
# Croper 3: croping............(38800/42452)
# Croper 2: croping............(38900/42450)
# Croper 1: croping............(38800/42450)
# Croper 3: croping............(38900/42452)
# Croper 2: croping............(39000/42450)
# Croper 1: croping............(38900/42450)
# Croper 3: croping............(39000/42452)
# Croper 2: croping............(39100/42450)
# Croper 1: croping............(39000/42450)
# Croper 3: croping............(39100/42452)
# Croper 2: croping............(39200/42450)
# Croper 1: croping............(39100/42450)
# Croper 3: croping............(39200/42452)
# Croper 2: croping............(39300/42450)
# Croper 1: croping............(39200/42450)
# Croper 3: croping............(39300/42452)
# Croper 2: croping............(39400/42450)
# Croper 1: croping............(39300/42450)
# Croper 3: croping............(39400/42452)
# Croper 2: croping............(39500/42450)
# Croper 1: croping............(39400/42450)
# Croper 3: croping............(39500/42452)
# Croper 2: croping............(39600/42450)
# Croper 1: croping............(39500/42450)
# Croper 3: croping............(39600/42452)
# Croper 2: croping............(39700/42450)
# Croper 1: croping............(39600/42450)
# Croper 3: croping............(39700/42452)
# Croper 2: croping............(39800/42450)
# Croper 1: croping............(39700/42450)
# Croper 3: croping............(39800/42452)
# Croper 2: croping............(39900/42450)
# Croper 1: croping............(39800/42450)
# Croper 3: croping............(39900/42452)
# Croper 2: croping............(40000/42450)
# Croper 1: croping............(39900/42450)
# Croper 3: croping............(40000/42452)
# Croper 2: croping............(40100/42450)
# Croper 1: croping............(40000/42450)
# Croper 3: croping............(40100/42452)
# Croper 2: croping............(40200/42450)
# Croper 1: croping............(40100/42450)
# Croper 3: croping............(40200/42452)
# Croper 2: croping............(40300/42450)
# Croper 1: croping............(40200/42450)
# Croper 3: croping............(40300/42452)
# Croper 2: croping............(40400/42450)
# Croper 1: croping............(40300/42450)
# Croper 3: croping............(40400/42452)
# Croper 2: croping............(40500/42450)
# Croper 1: croping............(40400/42450)
# Croper 3: croping............(40500/42452)
# Croper 2: croping............(40600/42450)
# Croper 1: croping............(40500/42450)
# Croper 3: croping............(40600/42452)
# Croper 2: croping............(40700/42450)
# Croper 1: croping............(40600/42450)
# Croper 3: croping............(40700/42452)
# Croper 2: croping............(40800/42450)
# Croper 1: croping............(40700/42450)
# Croper 3: croping............(40800/42452)
# Croper 2: croping............(40900/42450)
# Croper 1: croping............(40800/42450)
# Croper 3: croping............(40900/42452)
# Croper 2: croping............(41000/42450)
# Croper 1: croping............(40900/42450)
# Croper 3: croping............(41000/42452)
# Croper 2: croping............(41100/42450)
# Croper 1: croping............(41000/42450)
# Croper 3: croping............(41100/42452)
# Croper 2: croping............(41200/42450)
# Croper 1: croping............(41100/42450)
# Croper 3: croping............(41200/42452)
# Croper 2: croping............(41300/42450)
# Croper 1: croping............(41200/42450)
# Croper 3: croping............(41300/42452)
# Croper 2: croping............(41400/42450)
# Croper 1: croping............(41300/42450)
# Croper 3: croping............(41400/42452)
# Croper 2: croping............(41500/42450)
# Croper 1: croping............(41400/42450)
# Croper 3: croping............(41500/42452)
# Croper 2: croping............(41600/42450)
# Croper 1: croping............(41500/42450)
# Croper 3: croping............(41600/42452)
# Croper 2: croping............(41700/42450)
# Croper 1: croping............(41600/42450)
# Croper 3: croping............(41700/42452)
# Croper 2: croping............(41800/42450)
# Croper 1: croping............(41700/42450)
# Croper 3: croping............(41800/42452)
# Croper 2: croping............(41900/42450)
# Croper 1: croping............(41800/42450)
# Croper 3: croping............(41900/42452)
# Croper 2: croping............(42000/42450)
# Croper 1: croping............(41900/42450)
# Croper 3: croping............(42000/42452)
# Croper 2: croping............(42100/42450)
# Croper 1: croping............(42000/42450)
# Croper 3: croping............(42100/42452)
# Croper 2: croping............(42200/42450)
# Croper 1: croping............(42100/42450)
# Croper 3: croping............(42200/42452)
# Croper 2: croping............(42300/42450)
# Croper 1: croping............(42200/42450)
# Croper 3: croping............(42300/42452)
# Croper 2: croping............(42400/42450)
# Croper 1: croping............(42300/42450)
# Croper 3: croping............(42400/42452)
# Croper 1: croping............(42400/42450)

# %%
filename = clist[0]
out_name = '../datasets/danbooru-images/portrait/0{}'.format(filename[45:-4])
out_name = out_name.format(filename[38:-4])
print(out_name)
# Out:
# ../datasets/danbooru-images/portrait/0000/867000
